# %% [markdown]
# # NFL Player Performance - Trening i validacija modela
#
# Ovaj notebook predstavlja kompletan pipeline koji obuhvata predprocesiranje podataka, treniranje modela i njihovu evaluaciju. Ovaj notebook predstavlja nastavak EDA.ipynb i sve odluke i tehnike uradjene ovde, odredjenje su tokom ekplorativne analize prikazane u tom notebook-u.

# %% [markdown]
# ### Predprocesiranje podataka

# %%
import sys, os
sys.path.insert(0, os.path.abspath(''))

import warnings
warnings.filterwarnings('ignore')

from modeling.data_preprocessing import *
from modeling.missing_values import *
from modeling.lag_feature import *
from modeling.dataset_split import *
from training.model_saving import *
from training.plots import *
from training.calibration import *
from training.calibration_plots import *
from training.shap_analysis import *

DATA_DIR = os.path.join('..', 'data', 'fully combined')

datasets = load_datasets(DATA_DIR)
qb_raw = datasets['qb_raw']
rb_raw = datasets['rb_raw']
te_raw = datasets['te_raw']
wr_raw = datasets['wr_raw']
# Out:
# QB: 845 redova x 188 kolona | Sezone: 1979-2025
# RB: 622 redova x 115 kolona | Sezone: 1988-2025
# TE: 351 redova x 70 kolona | Sezone: 1990-2025
# WR: 5502 redova x 102 kolona | Sezone: 2015-2025

# %% [markdown]
# Kao sto je odredjeno tokom ekplorativne analize, pravimo ciljnu varijablu jardi po utakmici.

# %%
qb, rb, te = add_targets_qb_rb_te(qb_raw, rb_raw, te_raw)
wr = add_target_wr(wr_raw)

print_target_summary(qb, rb, te, wr)
# Out:
# Ciljne promenljive:
# QB (Yds/G):       mean=223.72, median=231.05, min=0.00, max=371.20 | Sezone: 1979-2025
# RB (Yds/G):       mean=63.07, median=65.16, min=-0.23, max=131.06 | Sezone: 1988-2025
# TE (Yds/G):       mean=39.37, median=39.07, min=0.00, max=94.40 | Sezone: 1990-2025
# WR (Yds/G raw):   mean=22.39, median=16.57, min=-16.00, max=116.94
# WR (log1p Yds/G): mean=2.737, median=2.866, min=0.000, max=4.770

# %% [markdown]
# Korišćenjem multi-label binary encoding-a transformišemo kategorijalnu promenljivu awars u pet novih binarhih kolona award_PB, award_AP1, award_AP2, award_MVP_top5, award_OPoY_top5.

# %%
qb, rb, te = apply_award_encoding(qb, rb, te)
print_award_summary(qb, rb, te)
# Out:
# Award encoding — broj sezona po kategoriji:
#
# Nagrada                  QB     RB     TE
# --------------------------------------
# award_PB                262    152     93
# award_AP1                40     52     28
# award_AP2                37     39     20
# award_MVP_top5           92     28      0
# award_OPoY_top5          89     46      4

# %% [markdown]
# Kao što je utvrđeno tokom ekplorativne analize imamo veliki broj nedostajućih vrednosti, koje se pojavljuju zbog velikog broja neodgovarajućih kolona, zbog čega ih izbacujemo.

# %%
analyze_nulls_by_position(qb, rb, te, wr)
# Out:
# =======================================================
#   QB — kolone sa null vrednostima (156 od 194)
# =======================================================
#   Kolona                               Null#   Null%
#   ----------------------------------------------------
#   adv_rr_rec_broken_tackles_per_rec      781   99.6%
#   adv_rr_rec_yac_per_rec                 748   95.4%
#   adv_rr_rec_air_yds_per_rec             748   95.4%
#   adv_rr_rec_adot                        736   93.9%
#   adv_rr_rec_pass_rating                 736   93.9%
#   adv_rr_rec_drop_pct                    736   93.9%
#   rr_rec_long                            686   87.5%
#   rr_rec_yds_per_rec                     686   87.5%
#   rr_rec_success                         657   83.8%
#   rr_rec_yds_per_tgt                     657   83.8%
#   rr_catch_pct                           657   83.8%
#   adv_rr_Rush_BrkTkl/A                   649   82.8%
#   adv_pass_pass_on_target_pct            557   71.0%
#   adv_pass_pass_rpo_rush_yds             556   70.9%
#   adv_pass_pass_rpo_pass_yds             556   70.9%
#   adv_pass_pass_rpo                      556   70.9%
#   adv_pass_pass_rpo_rush_att             556   70.9%
#   adv_pass_pass_rpo_yds                  556   70.9%
#   adv_pass_pass_play_action_pass_yds     556   70.9%
#   adv_pass_pass_play_action              556   70.9%
#   adv_pass_pass_on_target                556   70.9%
#   adv_pass_pass_rpo_pass_att             556   70.9%
#   adv_pass_rush_scrambles_yds_per_att    532   67.9%
#   adv_rr_Rush_YAC/A                      528   67.3%
#   adv_rr_Rush_YAC                        528   67.3%
#   adv_rr_Rush_BrkTkl                     528   67.3%
#   adv_rr_Rec_YAC                         528   67.3%
#   adv_rr_Rec_Int                         528   67.3%
#   adv_pass_pass_yac_per_cmp              528   67.3%
#   adv_rr_Rec_Drops                       528   67.3%
#   adv_rr_Rush_YBC                        528   67.3%
#   adv_rr_Rec_BrkTkl                      528   67.3%
#   adv_rr_Rec_AirYds                      528   67.3%
#   adv_rr_Rush_YBC/A                      528   67.3%
#   adv_pass_pass_air_yds_per_cmp          528   67.3%
#   adv_pass_pass_drop_pct                 528   67.3%
#   adv_pass_pass_poor_throw_pct           528   67.3%
#   adv_pass_pass_pressured_pct            527   67.2%
#   adv_pass_pass_hurried                  527   67.2%
#   adv_pass_pass_air_yds                  527   67.2%
#   adv_pass_pass_air_yds_per_att          527   67.2%
#   adv_pass_pass_batted_passes            527   67.2%
#   adv_pass_pass_blitzed                  527   67.2%
#   adv_pass_pass_drops                    527   67.2%
#   adv_pass_pass_hits                     527   67.2%
#   adv_pass_rush_scrambles                527   67.2%
#   adv_pass_pocket_time                   527   67.2%
#   adv_pass_pass_yac                      527   67.2%
#   adv_pass_pass_throwaways               527   67.2%
#   adv_pass_pass_tgt_yds_per_att          527   67.2%
#   adv_pass_pass_target_yds               527   67.2%
#   adv_pass_pass_spikes                   527   67.2%
#   adv_pass_pass_poor_throws              527   67.2%
#   adv_pass_pass_pressured                527   67.2%
#   snp_special_teams                      501   63.9%
#   snp_offense                            501   63.9%
#   snp_defense                            501   63.9%
#   snp_ST%                                501   63.9%
#   snp_Off%                               501   63.9%
#   snp_Def%                               501   63.9%
#   Awards                                 482   61.5%
#   elo_QBR                                385   49.1%
#   elo_CB%                                339   43.2%
#   def_qb_hits                            327   41.7%
#   elo_YPC                                326   41.6%
#   elo_CPOE                               323   41.2%
#   elo_Passer Rtg                         322   41.1%
#   elo_WPA / DB                           322   41.1%
#   elo_YAC                                322   41.1%
#   elo_YPA                                322   41.1%
#   elo_Change (Week)                      322   41.1%
#   elo_Carries                            322   41.1%
#   elo_CB                                 322   41.1%
#   elo_CB Opps                            322   41.1%
#   elo_Total WPA                          322   41.1%
#   elo_Atts                               322   41.1%
#   elo_Air Yards                          322   41.1%
#   elo_ANY/A                              322   41.1%
#   elo_/ DB                               322   41.1%
#   elo_Yards                              322   41.1%
#   elo_Yards.1                            322   41.1%
#   elo_aDOT                               322   41.1%
#   elo_W                                  322   41.1%
#   elo_Total                              322   41.1%
#   elo_L                                  322   41.1%
#   elo_Comp%                              322   41.1%
#   elo_Inc                                322   41.1%
#   elo_INTs.1                             322   41.1%
#   elo_Penalties                          322   41.1%
#   elo_Points                             322   41.1%
#   elo_QB Elo                             322   41.1%
#   elo_Rushing                            322   41.1%
#   elo_INTs                               322   41.1%
#   elo_INT%                               322   41.1%
#   elo_Comp                               322   41.1%
#   elo_TDs.1                              322   41.1%
#   elo_Sacks                              322   41.1%
#   elo_Starts                             322   41.1%
#   elo_Success                            322   41.1%
#   elo_T                                  322   41.1%
#   elo_TD%                                322   41.1%
#   elo_Change (Year)                      322   41.1%
#   elo_TD%-INT%                           322   41.1%
#   elo_TDs                                322   41.1%
#   elo_Sacks.1                            322   41.1%
#   elo_vs Sticks                          322   41.1%
#   QBR                                    266   33.9%
#   def_tackles_loss                       235   30.0%
#   def_pass_defended                      169   21.6%
#   def_tackles_solo                        47    6.0%
#   def_tackles_assists                     47    6.0%
#   def_tackles_combined                    47    6.0%
#   def_safety_md                           19    2.4%
#   def_FR_TD                               19    2.4%
#   def_sacks                               19    2.4%
#   def_FF                                  19    2.4%
#   def_FR                                  19    2.4%
#   def_FR_Yds                              19    2.4%
#   def_Fmb                                 19    2.4%
#   def_def_int                             19    2.4%
#   def_def_int_long                        19    2.4%
#   def_def_int_td                          19    2.4%
#   def_def_int_yds                         19    2.4%
#   adj_Rate+                               18    2.3%
#   adj_Y/A+                                18    2.3%
#   adj_TD%+                                18    2.3%
#   adj_Sack%+                              18    2.3%
#   adj_AY/A+                               18    2.3%
#   adj_NY/A+                               18    2.3%
#   adj_Int%+                               18    2.3%
#   adj_Cmp%+                               18    2.3%
#   adj_ANY/A+                              18    2.3%
#   rr_Rush_Lng                             10    1.3%
#   rr_Rec_TD                                4    0.5%
#   rr_Fmb                                   4    0.5%
#   rr_Rec                                   4    0.5%
#   rr_Rec/G                                 4    0.5%
#   rr_Rec_1D                                4    0.5%
#   rr_Rush_TD                               4    0.5%
#   rr_Rec_Y/G                               4    0.5%
#   rr_Rec_Yds                               4    0.5%
#   rr_yds_per_touch                         4    0.5%
#   rr_yds_from_scrimmage                    4    0.5%
#   rr_touches                               4    0.5%
#   rr_rush_receive_td                       4    0.5%
#   rr_Tgt                                   4    0.5%
#   rr_Rush_Yds                              4    0.5%
#   rr_Rush_Y/G                              4    0.5%
#   rr_Rush_Y/A                              4    0.5%
#   rr_Rush_Succ%                            4    0.5%
#   rr_Rush_Att                              4    0.5%
#   rr_Rush_A/G                              4    0.5%
#   rr_Rush_1D                               4    0.5%
#   Lng                                      1    0.1%
#   Y/C                                      1    0.1%
#   Succ%                                    1    0.1%
#
# =======================================================
#   RB — kolone sa null vrednostima (92 od 121)
# =======================================================
#   Kolona                               Null#   Null%
#   ----------------------------------------------------
#   snp_special_teams                      561   90.2%
#   snp_offense                            561   90.2%
#   snp_defense                            561   90.2%
#   def_tackles_loss                       544   87.5%
#   def_Def_IntTD                          542   87.1%
#   adv_Rec_Att/Br                         542   87.1%
#   def_Ast                                542   87.1%
#   def_Comb                               542   87.1%
#   def_Def_FR_Yds                         542   87.1%
#   def_Def_Lng                            542   87.1%
#   def_FRTD                               542   87.1%
#   def_Solo                               542   87.1%
#   def_safety_md                          542   87.1%
#   adv_ADOT                               539   86.7%
#   adv_rec_pass_rating                    539   86.7%
#   adv_Rec_YBC/R                          539   86.7%
#   adv_Drop%                              539   86.7%
#   adv_Rush_YBC/Att                       538   86.5%
#   adv_Rush_YAC/Att                       538   86.5%
#   adv_Rec_YBC                            538   86.5%
#   adv_Drop                               538   86.5%
#   adv_Rush_Att/Br                        538   86.5%
#   rec_long                               534   85.9%
#   rec_success                            533   85.7%
#   Y/Tgt                                  533   85.7%
#   catch_pct                              533   85.7%
#   yds_per_touch                          532   85.5%
#   Rec_R/G                                532   85.5%
#   yds_from_scrimmage                     532   85.5%
#   Lg                                     532   85.5%
#   rush_receive_td                        532   85.5%
#   Touch                                  532   85.5%
#   adv_Rec_BrkTkl/R                       486   78.1%
#   adv_Rush_BrkTkl/A                      473   76.0%
#   adv_Rec_AirYds/R                       466   74.9%
#   adv_Rec_aDOT                           466   74.9%
#   adv_Rec_Drop%                          466   74.9%
#   adv_Rec_PassRtg                        466   74.9%
#   adv_Rush_YBC/A                         462   74.3%
#   adv_Rush_YAC/A                         462   74.3%
#   adv_Rush_Att                           462   74.3%
#   adv_Rush_1D                            462   74.3%
#   adv_Rec_Yds                            462   74.3%
#   adv_Rush_Yds                           462   74.3%
#   adv_Rec_1D                             462   74.3%
#   adv_Rec_Drops                          462   74.3%
#   adv_Rec_AirYds                         462   74.3%
#   awards                                 441   70.9%
#   snp_Off%                               424   68.2%
#   snp_Def%                               424   68.2%
#   snp_ST%                                424   68.2%
#   snp_ST_Snaps                           417   67.0%
#   snp_Def_Snaps                          417   67.0%
#   snp_Off_Snaps                          417   67.0%
#   adv_Rec_YAC/R                          383   61.6%
#   adv_Rush_YBC                           378   60.8%
#   adv_Rush_YAC                           378   60.8%
#   adv_Rush_BrkTkl                        378   60.8%
#   adv_Rec_YAC                            378   60.8%
#   adv_Rec_Int                            378   60.8%
#   adv_Rec_BrkTkl                         378   60.8%
#   def_QBHits                             258   41.5%
#   def_TFL                                255   41.0%
#   def_Tkl_Ast                            171   27.5%
#   def_Tkl_Comb                           171   27.5%
#   def_Tkl_Solo                           171   27.5%
#   def_Def_Int_TD                         152   24.4%
#   def_Def_Int_Lng                        152   24.4%
#   def_FR_TD                              152   24.4%
#   def_FR_Yds                             152   24.4%
#   def_Sfty                               152   24.4%
#   def_PD                                 121   19.5%
#   Rec_Lng                                101   16.2%
#   Rec_Succ%                              100   16.1%
#   Rec_Y/Tgt                              100   16.1%
#   Catch%                                 100   16.1%
#   Y/Touch                                 93   15.0%
#   Scrimmage_Yds                           90   14.5%
#   Rec/G                                   90   14.5%
#   Rush_Rec_TD                             90   14.5%
#   Touches                                 90   14.5%
#   def_Fmb                                 72   11.6%
#   def_Sk                                  72   11.6%
#   def_Def_Int_Yds                         72   11.6%
#   def_FF                                  72   11.6%
#   def_FR                                  72   11.6%
#   def_Def_Int                             72   11.6%
#   Rec_Y/R                                 13    2.1%
#   Rush_Succ%                               3    0.5%
#   Rush_Y/A                                 3    0.5%
#   Rush_Lng                                 3    0.5%
#   av                                       2    0.3%
#
# =======================================================
#   TE — kolone sa null vrednostima (42 od 76)
# =======================================================
#   Kolona                               Null#   Null%
#   ----------------------------------------------------
#   adv_Rush_Att/Br                        349   99.7%
#   adv_Rec_YBC                            348   99.4%
#   adv_Rec_Att/Br                         348   99.4%
#   adv_Rec_YBC/R                          348   99.4%
#   adv_Rush_BrkTkl/A                      346   98.9%
#   adv_Rush_YBC/A                         294   84.0%
#   adv_Rush_YAC/A                         294   84.0%
#   Rush_Lng                               290   82.9%
#   Rush_Succ%                             280   80.0%
#   Rush_Y/A                               280   80.0%
#   Awards                                 251   71.7%
#   adv_Rec_BrkTkl/R                       190   54.3%
#   adv_Rec_AirYds/R                       149   42.6%
#   adv_Rec_PassRtg                        147   42.0%
#   adv_Rush_1D                            147   42.0%
#   adv_Rec_aDOT                           147   42.0%
#   adv_Rush_Att                           147   42.0%
#   adv_Rec_Yds                            147   42.0%
#   adv_Rec_YAC/R                          147   42.0%
#   adv_Rush_Yds                           147   42.0%
#   adv_Rec_Drop%                          147   42.0%
#   adv_Rec_AirYds                         147   42.0%
#   adv_Rec_1D                             147   42.0%
#   adv_Rec_Int                            145   41.4%
#   adv_Rec_YAC                            145   41.4%
#   adv_Rec_BrkTkl                         145   41.4%
#   adv_Rush_BrkTkl                        145   41.4%
#   adv_Rush_YAC                           145   41.4%
#   adv_Rush_YBC                           145   41.4%
#   adv_Rec_Drops                          145   41.4%
#   snp_Def%                               130   37.1%
#   snp_Off%                               130   37.1%
#   snp_ST%                                130   37.1%
#   snp_Def_Snaps                          128   36.6%
#   snp_Off_Snaps                          128   36.6%
#   snp_ST_Snaps                           128   36.6%
#   Rec_Succ%                                3    0.9%
#   Y/Touch                                  3    0.9%
#   Rec_Y/Tgt                                3    0.9%
#   Catch%                                   3    0.9%
#   Rec_Lng                                  3    0.9%
#   Rec_Y/R                                  3    0.9%
#
# =======================================================
#   WR — kolone sa null vrednostima (0 od 104)
# =======================================================
#   Nema null vrednosti.

# %%
qb, rb, te = drop_metadata_columns_qb_rb_te(qb, rb, te)
wr = drop_unused_columns_wr(wr)
adv_cols_to_drop = [c for c in qb.columns if c.startswith('adv_')]
qb.drop(columns=adv_cols_to_drop, inplace=True)
qb, rb, te, wr = drop_rr_snp_adv_columns(qb, rb, te, wr)
qb, rb, te = drop_awards_raw(qb, rb, te)
qb = drop_qb_qbr(qb)
rb = drop_rb_receiving_cols(rb)
te = drop_te_rushing_cols(te)
wr = drop_wr_def_dev_cols(wr)

# %%
print_shape_and_columns(qb, rb, te, wr)
# Out:
# Pozicija  Kolona  Redova
# -------------------------
# QB          42     784
# RB          24     622
# TE          29     350
# WR          48    5502
#
# ============================================================
#   QB — 42 kolona x 784 redova
# ============================================================
#     1. Player
#     2. Season
#     3. Age
#     4. Team
#     5. G
#     6. GS
#     7. Cmp
#     8. Att
#     9. Cmp%
#    10. Yds
#    11. TD
#    12. Int
#    13. 1D
#    14. Succ%
#    15. Y/A
#    16. AY/A
#    17. Y/C
#    18. Rate
#    19. Sk
#    20. Yds_Lost
#    21. NY/A
#    22. ANY/A
#    23. 4QC
#    24. GWD
#    25. AV
#    26. adj_ANY/A+
#    27. adj_AY/A+
#    28. adj_Cmp%+
#    29. adj_Int%+
#    30. adj_NY/A+
#    31. adj_Rate+
#    32. adj_Sack%+
#    33. adj_TD%+
#    34. adj_Y/A+
#    35. Team_Changed
#    36. Prev_Season_Yds
#    37. target
#    38. award_PB
#    39. award_AP1
#    40. award_AP2
#    41. award_MVP_top5
#    42. award_OPoY_top5
#
# ============================================================
#   RB — 24 kolona x 622 redova
# ============================================================
#     1. Player
#     2. Season
#     3. Age
#     4. Team
#     5. G
#     6. GS
#     7. Rush_Att
#     8. Rush_Yds
#     9. Rush_TD
#    10. Rush_1D
#    11. Rush_Succ%
#    12. Rush_Lng
#    13. Rush_Y/A
#    14. Rush_A/G
#    15. Fmb
#    16. av
#    17. Team_Changed
#    18. Prev_Season_Yds
#    19. target
#    20. award_PB
#    21. award_AP1
#    22. award_AP2
#    23. award_MVP_top5
#    24. award_OPoY_top5
#
# ============================================================
#   TE — 29 kolona x 350 redova
# ============================================================
#     1. Player
#     2. Season
#     3. Age
#     4. Team
#     5. G
#     6. GS
#     7. Tgt
#     8. Rec
#     9. Rec_Yds
#    10. Rec_Y/R
#    11. Rec_TD
#    12. Rec_1D
#    13. Rec_Succ%
#    14. Rec_Lng
#    15. Rec/G
#    16. Rec_Y/G
#    17. Catch%
#    18. Rec_Y/Tgt
#    19. Rush_Rec_TD
#    20. Fmb
#    21. AV
#    22. Team_Changed
#    23. Prev_Season_Yds
#    24. target
#    25. award_PB
#    26. award_AP1
#    27. award_AP2
#    28. award_MVP_top5
#    29. award_OPoY_top5
#
# ============================================================
#   WR — 48 kolona x 5502 redova
# ============================================================
#     1. receiver_player_name
#     2. season
#     3. games_played
#     4. posteam
#     5. targets
#     6. receptions
#     7. receiving_yards
#     8. air_yards
#     9. yac
#    10. tds
#    11. red_zone_targets
#    12. end_zone_targets
#    13. third_down_targets
#    14. fourth_down_targets
#    15. high_leverage_targets
#    16. explosive_plays
#    17. first_downs
#    18. second_and_long_targets
#    19. third_and_medium_targets
#    20. lost_yards_due_to_penalty
#    21. epa
#    22. wpa
#    23. avg_depth
#    24. catch_rate
#    25. team_pass_attempts
#    26. team_air_yards
#    27. team_epa
#    28. air_yard_share
#    29. target_share
#    30. yards_per_target
#    31. qb_completions
#    32. qb_attempts
#    33. qb_air_yards
#    34. qb_cpoe
#    35. qb_comp_pct
#    36. adot
#    37. yac_per_reception
#    38. td_rate
#    39. target_share_std
#    40. success_rate
#    41. big_play_rate
#    42. reception_std
#    43. avg_start_yardline
#    44. avg_target_depth_vs_qb
#    45. team_changed
#    46. prev_season_rec_yds
#    47. rec_yds_per_game
#    48. target

# %% [markdown]
# Nakon selekcije kolona vidimo da se problem sa ogromnim brojem null vrednosti rešio.

# %%
analyze_nulls_by_position(qb, rb, te, wr)
# Out:
# =======================================================
#   QB — kolone sa null vrednostima (11 od 42)
# =======================================================
#   Kolona                               Null#   Null%
#   ----------------------------------------------------
#   adj_ANY/A+                              18    2.3%
#   adj_AY/A+                               18    2.3%
#   adj_Cmp%+                               18    2.3%
#   adj_Int%+                               18    2.3%
#   adj_NY/A+                               18    2.3%
#   adj_Rate+                               18    2.3%
#   adj_Sack%+                              18    2.3%
#   adj_TD%+                                18    2.3%
#   adj_Y/A+                                18    2.3%
#   Succ%                                    1    0.1%
#   Y/C                                      1    0.1%
#
# =======================================================
#   RB — kolone sa null vrednostima (4 od 24)
# =======================================================
#   Kolona                               Null#   Null%
#   ----------------------------------------------------
#   Rush_Succ%                               3    0.5%
#   Rush_Lng                                 3    0.5%
#   Rush_Y/A                                 3    0.5%
#   av                                       2    0.3%
#
# =======================================================
#   TE — kolone sa null vrednostima (5 od 29)
# =======================================================
#   Kolona                               Null#   Null%
#   ----------------------------------------------------
#   Rec_Y/R                                  3    0.9%
#   Rec_Succ%                                3    0.9%
#   Rec_Lng                                  3    0.9%
#   Catch%                                   3    0.9%
#   Rec_Y/Tgt                                3    0.9%
#
# =======================================================
#   WR — kolone sa null vrednostima (0 od 48)
# =======================================================
#   Nema null vrednosti.

# %% [markdown]
# Lag features su mehanizam za uključivanje historijskih podataka igrača u model predikcije performanse, bez curenja podataka iz tekuće sezone. Za svaku poziciju, build_lag_features kreira matricu gdje se numeričke kolone (npr. Yds, TD) repliciraju kao _lag1 (vrijednosti iz sezone t-1) i _lag2 (t-2), dok statičke kolone (kao Age ili Team_Changed) ostaju nepromijenjene. Lag-2 NaN-ovi se pune nulom (nema historije), a lag-1 NaN-ovi ostaju za imputaciju, osiguravajući da model uči isključivo iz prošlosti za predikciju sezone t. build_all_lag_matrices primjenjuje ovo na sve pozicije prema konfiguraciji, rezultirajući feature matricama spremnim za trening.

# %%
POS_CONFIG = {
    'QB': dict(df=qb, player_col='Player', season_col='Season',
               static_feats=['Age', 'Team_Changed'],
               id_cols=['Player', 'Season', 'Team']),
    'RB': dict(df=rb, player_col='Player', season_col='Season',
               static_feats=['Age', 'Team_Changed'],
               id_cols=['Player', 'Season', 'Team']),
    'TE': dict(df=te, player_col='Player', season_col='Season',
               static_feats=['Age', 'Team_Changed'],
               id_cols=['Player', 'Season', 'Team']),
    'WR': dict(df=wr, player_col='receiver_player_name', season_col='season',
               static_feats=['age', 'team_changed'],
               id_cols=['receiver_player_name', 'season', 'posteam']),
}

lagged = build_all_lag_matrices(POS_CONFIG)

# %% [markdown]
# Funkcija build_train_test_splits vrši temporalni split podataka za svaku poziciju, koristeći sezone pre 2024. godine za trening skup (train), dok sezona 2024. služi kao test skup. Ovo osigurava da model trenira na istorijskim podacima bez curenja informacija iz budućnosti, simulirajući realne uslove predikcije gde su podaci iz budućih sezona nedostupni tokom treninga. Za svaku poziciju vraća features (X) i target (y) za trening i test, omogućavajući evaluaciju modela na neviđenim podacima iz 2024.

# %%
POS_SPLIT = {
    'QB': dict(id_cols=['Player', 'Season', 'Team'],                    season_col='Season'),
    'RB': dict(id_cols=['Player', 'Season', 'Team'],                    season_col='Season'),
    'TE': dict(id_cols=['Player', 'Season', 'Team'],                    season_col='Season'),
    'WR': dict(id_cols=['receiver_player_name', 'season', 'posteam'],   season_col='season'),
}

splits = build_train_test_splits(lagged, POS_SPLIT)
print_split_summary(splits)
# Out:
# Pos      X_train   X_test   y_train   y_test   features
# -------------------------------------------------------
# QB           714       35       714       35         74
# RB           552       34       552       34         38
# TE           295       28       295       28         48
# WR          5393      558      5393      558         87

# %% [markdown]
# Ovde vršimo predprocesiranje podataka za trening i test skupove: prvo popunjavamo lag-2 features (koji mogu biti prazni za igrače sa manje od dve sezone) nulama, zatim imputiramo preostale nedostajuće vrednosti medianom, i na kraju skaliramo numeričke features na standardnu normalnu distribuciju koristeći StandardScaler, dok binarne kolone ostavljamo nepromenjene kako bi zadržale svoju kategorijsku prirodu. Važno je napomenuti da se StandardScaler fituje isključivo na trening podacima, a zatim transformišemo i trening i test skup, čime se izbegava data leakage.

# %%
BINARY_COLS = [
    'award_PB_lag1',       'award_AP1_lag1',       'award_AP2_lag1',
    'award_MVP_top5_lag1', 'award_OPoY_top5_lag1',
    'award_PB_lag2',       'award_AP1_lag2',       'award_AP2_lag2',
    'award_MVP_top5_lag2', 'award_OPoY_top5_lag2',
    'Team_Changed', 'team_changed',
]

processed = {}
for pos, (X_train, X_test, y_train, y_test) in splits.items():
    X_train, X_test = impute_lag2_zeros(X_train, X_test)
    X_train, X_test = impute_median(X_train, X_test)
    X_train, X_test = scale_features(X_train, X_test, BINARY_COLS)
    processed[pos]  = (X_train, X_test, y_train, y_test)

print_processed_summary(processed, BINARY_COLS)
# Out:
# Pos    X_train nulls  X_test nulls  scaled cols  binary cols
# ------------------------------------------------------------
# QB                 0             0           63           11
# RB                 0             0           27           11
# TE                 0             0           37           11
# WR                 0             0           86            1

# %% [markdown]
# Proces predprocesiranja dataseta je gotov i podaci su spremni za treniranje modela.

# %%
print_processed_columns(processed)
# Out:
# =================================================================
#   QB — X_train: 714 redova x 74 kolona
# =================================================================
#
#      #  Kolona                                             Tip   Nulls
#   ----------------------------------------------------------------------
#      1. Age                                            float64       0
#      2. Team_Changed                                   float64       0
#      3. G_lag1                                         float64       0
#      4. GS_lag1                                        float64       0
#      5. Cmp_lag1                                       float64       0
#      6. Att_lag1                                       float64       0
#      7. Cmp%_lag1                                      float64       0
#      8. Yds_lag1                                       float64       0
#      9. TD_lag1                                        float64       0
#     10. Int_lag1                                       float64       0
#     11. 1D_lag1                                        float64       0
#     12. Succ%_lag1                                     float64       0
#     13. Y/A_lag1                                       float64       0
#     14. AY/A_lag1                                      float64       0
#     15. Y/C_lag1                                       float64       0
#     16. Rate_lag1                                      float64       0
#     17. Sk_lag1                                        float64       0
#     18. Yds_Lost_lag1                                  float64       0
#     19. NY/A_lag1                                      float64       0
#     20. ANY/A_lag1                                     float64       0
#     21. 4QC_lag1                                       float64       0
#     22. GWD_lag1                                       float64       0
#     23. AV_lag1                                        float64       0
#     24. adj_ANY/A+_lag1                                float64       0
#     25. adj_AY/A+_lag1                                 float64       0
#     26. adj_Cmp%+_lag1                                 float64       0
#     27. adj_Int%+_lag1                                 float64       0
#     28. adj_NY/A+_lag1                                 float64       0
#     29. adj_Rate+_lag1                                 float64       0
#     30. adj_Sack%+_lag1                                float64       0
#     31. adj_TD%+_lag1                                  float64       0
#     32. adj_Y/A+_lag1                                  float64       0
#     33. Prev_Season_Yds_lag1                           float64       0
#     34. award_PB_lag1                                  float64       0
#     35. award_AP1_lag1                                 float64       0
#     36. award_AP2_lag1                                 float64       0
#     37. award_MVP_top5_lag1                            float64       0
#     38. award_OPoY_top5_lag1                           float64       0
#     39. G_lag2                                         float64       0
#     40. GS_lag2                                        float64       0
#     41. Cmp_lag2                                       float64       0
#     42. Att_lag2                                       float64       0
#     43. Cmp%_lag2                                      float64       0
#     44. Yds_lag2                                       float64       0
#     45. TD_lag2                                        float64       0
#     46. Int_lag2                                       float64       0
#     47. 1D_lag2                                        float64       0
#     48. Succ%_lag2                                     float64       0
#     49. Y/A_lag2                                       float64       0
#     50. AY/A_lag2                                      float64       0
#     51. Y/C_lag2                                       float64       0
#     52. Rate_lag2                                      float64       0
#     53. Sk_lag2                                        float64       0
#     54. Yds_Lost_lag2                                  float64       0
#     55. NY/A_lag2                                      float64       0
#     56. ANY/A_lag2                                     float64       0
#     57. 4QC_lag2                                       float64       0
#     58. GWD_lag2                                       float64       0
#     59. AV_lag2                                        float64       0
#     60. adj_ANY/A+_lag2                                float64       0
#     61. adj_AY/A+_lag2                                 float64       0
#     62. adj_Cmp%+_lag2                                 float64       0
#     63. adj_Int%+_lag2                                 float64       0
#     64. adj_NY/A+_lag2                                 float64       0
#     65. adj_Rate+_lag2                                 float64       0
#     66. adj_Sack%+_lag2                                float64       0
#     67. adj_TD%+_lag2                                  float64       0
#     68. adj_Y/A+_lag2                                  float64       0
#     69. Prev_Season_Yds_lag2                           float64       0
#     70. award_PB_lag2                                  float64       0
#     71. award_AP1_lag2                                 float64       0
#     72. award_AP2_lag2                                 float64       0
#     73. award_MVP_top5_lag2                            float64       0
#     74. award_OPoY_top5_lag2                           float64       0
#
#   Ukupno null-ova u X_train: 0
#   Ukupno null-ova u X_test:  0
#   y_train nulls: 0 | y_test nulls: 0
#
# =================================================================
#   RB — X_train: 552 redova x 38 kolona
# =================================================================
#
#      #  Kolona                                             Tip   Nulls
#   ----------------------------------------------------------------------
#      1. Age                                            float64       0
#      2. Team_Changed                                   float64       0
#      3. G_lag1                                         float64       0
#      4. GS_lag1                                        float64       0
#      5. Rush_Att_lag1                                  float64       0
#      6. Rush_Yds_lag1                                  float64       0
#      7. Rush_TD_lag1                                   float64       0
#      8. Rush_1D_lag1                                   float64       0
#      9. Rush_Succ%_lag1                                float64       0
#     10. Rush_Lng_lag1                                  float64       0
#     11. Rush_Y/A_lag1                                  float64       0
#     12. Rush_A/G_lag1                                  float64       0
#     13. Fmb_lag1                                       float64       0
#     14. av_lag1                                        float64       0
#     15. Prev_Season_Yds_lag1                           float64       0
#     16. award_PB_lag1                                  float64       0
#     17. award_AP1_lag1                                 float64       0
#     18. award_AP2_lag1                                 float64       0
#     19. award_MVP_top5_lag1                            float64       0
#     20. award_OPoY_top5_lag1                           float64       0
#     21. G_lag2                                         float64       0
#     22. GS_lag2                                        float64       0
#     23. Rush_Att_lag2                                  float64       0
#     24. Rush_Yds_lag2                                  float64       0
#     25. Rush_TD_lag2                                   float64       0
#     26. Rush_1D_lag2                                   float64       0
#     27. Rush_Succ%_lag2                                float64       0
#     28. Rush_Lng_lag2                                  float64       0
#     29. Rush_Y/A_lag2                                  float64       0
#     30. Rush_A/G_lag2                                  float64       0
#     31. Fmb_lag2                                       float64       0
#     32. av_lag2                                        float64       0
#     33. Prev_Season_Yds_lag2                           float64       0
#     34. award_PB_lag2                                  float64       0
#     35. award_AP1_lag2                                 float64       0
#     36. award_AP2_lag2                                 float64       0
#     37. award_MVP_top5_lag2                            float64       0
#     38. award_OPoY_top5_lag2                           float64       0
#
#   Ukupno null-ova u X_train: 0
#   Ukupno null-ova u X_test:  0
#   y_train nulls: 0 | y_test nulls: 0
#
# =================================================================
#   TE — X_train: 295 redova x 48 kolona
# =================================================================
#
#      #  Kolona                                             Tip   Nulls
#   ----------------------------------------------------------------------
#      1. Age                                            float64       0
#      2. Team_Changed                                   float64       0
#      3. G_lag1                                         float64       0
#      4. GS_lag1                                        float64       0
#      5. Tgt_lag1                                       float64       0
#      6. Rec_lag1                                       float64       0
#      7. Rec_Yds_lag1                                   float64       0
#      8. Rec_Y/R_lag1                                   float64       0
#      9. Rec_TD_lag1                                    float64       0
#     10. Rec_1D_lag1                                    float64       0
#     11. Rec_Succ%_lag1                                 float64       0
#     12. Rec_Lng_lag1                                   float64       0
#     13. Rec/G_lag1                                     float64       0
#     14. Rec_Y/G_lag1                                   float64       0
#     15. Catch%_lag1                                    float64       0
#     16. Rec_Y/Tgt_lag1                                 float64       0
#     17. Rush_Rec_TD_lag1                               float64       0
#     18. Fmb_lag1                                       float64       0
#     19. AV_lag1                                        float64       0
#     20. Prev_Season_Yds_lag1                           float64       0
#     21. award_PB_lag1                                  float64       0
#     22. award_AP1_lag1                                 float64       0
#     23. award_AP2_lag1                                 float64       0
#     24. award_MVP_top5_lag1                            float64       0
#     25. award_OPoY_top5_lag1                           float64       0
#     26. G_lag2                                         float64       0
#     27. GS_lag2                                        float64       0
#     28. Tgt_lag2                                       float64       0
#     29. Rec_lag2                                       float64       0
#     30. Rec_Yds_lag2                                   float64       0
#     31. Rec_Y/R_lag2                                   float64       0
#     32. Rec_TD_lag2                                    float64       0
#     33. Rec_1D_lag2                                    float64       0
#     34. Rec_Succ%_lag2                                 float64       0
#     35. Rec_Lng_lag2                                   float64       0
#     36. Rec/G_lag2                                     float64       0
#     37. Rec_Y/G_lag2                                   float64       0
#     38. Catch%_lag2                                    float64       0
#     39. Rec_Y/Tgt_lag2                                 float64       0
#     40. Rush_Rec_TD_lag2                               float64       0
#     41. Fmb_lag2                                       float64       0
#     42. AV_lag2                                        float64       0
#     43. Prev_Season_Yds_lag2                           float64       0
#     44. award_PB_lag2                                  float64       0
#     45. award_AP1_lag2                                 float64       0
#     46. award_AP2_lag2                                 float64       0
#     47. award_MVP_top5_lag2                            float64       0
#     48. award_OPoY_top5_lag2                           float64       0
#
#   Ukupno null-ova u X_train: 0
#   Ukupno null-ova u X_test:  0
#   y_train nulls: 0 | y_test nulls: 0
#
# =================================================================
#   WR — X_train: 5393 redova x 87 kolona
# =================================================================
#
#      #  Kolona                                             Tip   Nulls
#   ----------------------------------------------------------------------
#      1. team_changed                                   float64       0
#      2. games_played_lag1                              float64       0
#      3. targets_lag1                                   float64       0
#      4. receptions_lag1                                float64       0
#      5. receiving_yards_lag1                           float64       0
#      6. air_yards_lag1                                 float64       0
#      7. yac_lag1                                       float64       0
#      8. tds_lag1                                       float64       0
#      9. red_zone_targets_lag1                          float64       0
#     10. end_zone_targets_lag1                          float64       0
#     11. third_down_targets_lag1                        float64       0
#     12. fourth_down_targets_lag1                       float64       0
#     13. high_leverage_targets_lag1                     float64       0
#     14. explosive_plays_lag1                           float64       0
#     15. first_downs_lag1                               float64       0
#     16. second_and_long_targets_lag1                   float64       0
#     17. third_and_medium_targets_lag1                  float64       0
#     18. lost_yards_due_to_penalty_lag1                 float64       0
#     19. epa_lag1                                       float64       0
#     20. wpa_lag1                                       float64       0
#     21. avg_depth_lag1                                 float64       0
#     22. catch_rate_lag1                                float64       0
#     23. team_pass_attempts_lag1                        float64       0
#     24. team_air_yards_lag1                            float64       0
#     25. team_epa_lag1                                  float64       0
#     26. air_yard_share_lag1                            float64       0
#     27. target_share_lag1                              float64       0
#     28. yards_per_target_lag1                          float64       0
#     29. qb_completions_lag1                            float64       0
#     30. qb_attempts_lag1                               float64       0
#     31. qb_air_yards_lag1                              float64       0
#     32. qb_cpoe_lag1                                   float64       0
#     33. qb_comp_pct_lag1                               float64       0
#     34. adot_lag1                                      float64       0
#     35. yac_per_reception_lag1                         float64       0
#     36. td_rate_lag1                                   float64       0
#     37. target_share_std_lag1                          float64       0
#     38. success_rate_lag1                              float64       0
#     39. big_play_rate_lag1                             float64       0
#     40. reception_std_lag1                             float64       0
#     41. avg_start_yardline_lag1                        float64       0
#     42. avg_target_depth_vs_qb_lag1                    float64       0
#     43. prev_season_rec_yds_lag1                       float64       0
#     44. rec_yds_per_game_lag1                          float64       0
#     45. games_played_lag2                              float64       0
#     46. targets_lag2                                   float64       0
#     47. receptions_lag2                                float64       0
#     48. receiving_yards_lag2                           float64       0
#     49. air_yards_lag2                                 float64       0
#     50. yac_lag2                                       float64       0
#     51. tds_lag2                                       float64       0
#     52. red_zone_targets_lag2                          float64       0
#     53. end_zone_targets_lag2                          float64       0
#     54. third_down_targets_lag2                        float64       0
#     55. fourth_down_targets_lag2                       float64       0
#     56. high_leverage_targets_lag2                     float64       0
#     57. explosive_plays_lag2                           float64       0
#     58. first_downs_lag2                               float64       0
#     59. second_and_long_targets_lag2                   float64       0
#     60. third_and_medium_targets_lag2                  float64       0
#     61. lost_yards_due_to_penalty_lag2                 float64       0
#     62. epa_lag2                                       float64       0
#     63. wpa_lag2                                       float64       0
#     64. avg_depth_lag2                                 float64       0
#     65. catch_rate_lag2                                float64       0
#     66. team_pass_attempts_lag2                        float64       0
#     67. team_air_yards_lag2                            float64       0
#     68. team_epa_lag2                                  float64       0
#     69. air_yard_share_lag2                            float64       0
#     70. target_share_lag2                              float64       0
#     71. yards_per_target_lag2                          float64       0
#     72. qb_completions_lag2                            float64       0
#     73. qb_attempts_lag2                               float64       0
#     74. qb_air_yards_lag2                              float64       0
#     75. qb_cpoe_lag2                                   float64       0
#     76. qb_comp_pct_lag2                               float64       0
#     77. adot_lag2                                      float64       0
#     78. yac_per_reception_lag2                         float64       0
#     79. td_rate_lag2                                   float64       0
#     80. target_share_std_lag2                          float64       0
#     81. success_rate_lag2                              float64       0
#     82. big_play_rate_lag2                             float64       0
#     83. reception_std_lag2                             float64       0
#     84. avg_start_yardline_lag2                        float64       0
#     85. avg_target_depth_vs_qb_lag2                    float64       0
#     86. prev_season_rec_yds_lag2                       float64       0
#     87. rec_yds_per_game_lag2                          float64       0
#
#   Ukupno null-ova u X_train: 0
#   Ukupno null-ova u X_test:  0
#   y_train nulls: 0 | y_test nulls: 0

# %% [markdown]
# ### Trening i evaluacija modela
#
# Sledi proces treniranja modela. Izabran je veliki broj modela, od najjednostavnijih kao što je linearna regresija, preko regresionih modela, do složenijih neliarnih modela kao sto je Radnom Forest. Za svaki model sa hiperparametrima odradjena je optimizacija parametara korišćenjem 5-fold cross validacije.

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import numpy as np, pandas as pd, copy

MODEL_CONFIGS = {
    'LinearRegression': {
        'model': LinearRegression(),
        'params': {},
    },
    'Ridge': {
        'model': Ridge(),
        'params': {'alpha': [0.01, 0.1, 1.0, 10.0, 100.0]},
    },
    'Lasso': {
        'model': Lasso(max_iter=10000),
        'params': {'alpha': [0.001, 0.01, 0.1, 1.0]},
    },
    'ElasticNet': {
        'model': ElasticNet(max_iter=10000),
        'params': {'alpha': [0.01, 0.1, 1.0], 'l1_ratio': [0.1, 0.5, 0.9]},
    },
    'KNeighbors': {
        'model': KNeighborsRegressor(),
        'params': {'n_neighbors': [3, 5, 7, 9, 11, 15], 'weights': ['uniform', 'distance']},
    },
    'RandomForest': {
        'model': RandomForestRegressor(random_state=42, n_jobs=-1),
        'params': {
            'n_estimators': [100, 200, 300],
            'max_depth': [5, 10, None],
            'min_samples_split': [2, 5],
        },
    },
    'XGBoost': {
        'model': XGBRegressor(random_state=42, n_jobs=-1, verbosity=0),
        'params': {
            'n_estimators': [100, 200, 300],
            'max_depth': [3, 5, 7],
            'learning_rate': [0.01, 0.05, 0.1],
            'subsample': [0.8, 1.0],
        },
    },
    'LightGBM': {
        'model': LGBMRegressor(random_state=42, n_jobs=-1, verbosity=-1),
        'params': {
            'n_estimators': [100, 200, 300],
            'max_depth': [3, 5, 7],
            'learning_rate': [0.01, 0.05, 0.1],
            'num_leaves': [15, 31, 63],
        },
    },
}

tscv = TimeSeriesSplit(n_splits=5)

best_estimators = {}  
cv_results      = {}   

for pos, (X_tr, X_te, y_tr, y_te) in processed.items():
    best_estimators[pos] = {}
    rows = []
    log_note = ' [log skala]' if pos == 'WR' else ''

    print(f'\n{"="*68}')
    print(f'  {pos} — GridSearchCV (n_train={len(X_tr)}){log_note}')
    print(f'{"="*68}')
    print(f'  {"Model":<20} {"CV MAE":>8}  {"Najbolji parametri"}')
    print(f'  {"-"*65}')

    for name, cfg in MODEL_CONFIGS.items():
        if cfg['params']:
            grid = GridSearchCV(
                copy.deepcopy(cfg['model']),
                cfg['params'],
                cv=tscv,
                scoring='neg_mean_absolute_error',
                n_jobs=-1,
                refit=True,
            )
            grid.fit(X_tr, y_tr)
            best_model = grid.best_estimator_
            cv_mae     = -grid.best_score_
            best_params = grid.best_params_
        else:
            best_model = copy.deepcopy(cfg['model'])
            best_model.fit(X_tr, y_tr)
            cv_mae = -cross_val_score(
                copy.deepcopy(cfg['model']), X_tr, y_tr,
                cv=tscv, scoring='neg_mean_absolute_error', n_jobs=-1
            ).mean()
            best_params = {}

        best_estimators[pos][name] = best_model
        rows.append({'Model': name, 'CV_MAE': round(cv_mae, 3), 'Best_params': str(best_params)})
        params_str = str(best_params) if best_params else '-'
        print(f'  {name:<20} {cv_mae:>8.3f}  {params_str}')

    cv_results[pos] = pd.DataFrame(rows).set_index('Model')

print('\nGridSearchCV završen za sve pozicije.')
# Out:
# ====================================================================
#   QB — GridSearchCV (n_train=714)
# ====================================================================
#   Model                  CV MAE  Najbolji parametri
#   -----------------------------------------------------------------
#   LinearRegression       45.968  -
#   Ridge                  35.257  {'alpha': 100.0}
#   Lasso                  35.186  {'alpha': 1.0}
#   ElasticNet             34.930  {'alpha': 0.1, 'l1_ratio': 0.1}
#   KNeighbors             36.541  {'n_neighbors': 15, 'weights': 'uniform'}
#   RandomForest           35.494  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
#   XGBoost                35.643  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#   LightGBM               35.818  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#
# ====================================================================
#   RB — GridSearchCV (n_train=552)
# ====================================================================
#   Model                  CV MAE  Najbolji parametri
#   -----------------------------------------------------------------
#   LinearRegression       19.705  -
#   Ridge                  18.004  {'alpha': 100.0}
#   Lasso                  18.021  {'alpha': 1.0}
#   ElasticNet             17.952  {'alpha': 0.1, 'l1_ratio': 0.1}
#   KNeighbors             18.620  {'n_neighbors': 15, 'weights': 'distance'}
#   RandomForest           18.334  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
#   XGBoost                18.675  {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}
#   LightGBM               18.408  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#
# ====================================================================
#   TE — GridSearchCV (n_train=295)
# ====================================================================
#   Model                  CV MAE  Najbolji parametri
#   -----------------------------------------------------------------
#   LinearRegression       23.743  -
#   Ridge                  12.021  {'alpha': 100.0}
#   Lasso                  12.370  {'alpha': 1.0}
#   ElasticNet             12.397  {'alpha': 1.0, 'l1_ratio': 0.1}
#   KNeighbors             12.748  {'n_neighbors': 7, 'weights': 'uniform'}
#   RandomForest           12.324  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
#   XGBoost                12.568  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#   LightGBM               12.498  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 15}
#
# ====================================================================
#   WR — GridSearchCV (n_train=5393) [log skala]
# ====================================================================
#   Model                  CV MAE  Najbolji parametri
#   -----------------------------------------------------------------
#   LinearRegression        0.694  -
#   Ridge                   0.681  {'alpha': 100.0}
#   Lasso                   0.676  {'alpha': 0.01}
#   ElasticNet              0.676  {'alpha': 0.01, 'l1_ratio': 0.9}
#   KNeighbors              0.707  {'n_neighbors': 15, 'weights': 'uniform'}
#   RandomForest            0.680  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
#   XGBoost                 0.673  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#   LightGBM                0.672  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#
# GridSearchCV završen za sve pozicije.

# %% [markdown]
# Sledeci korak je validacija na test skupu.

# %%
test_results = {}   
best_models  = {}   

for pos, (X_tr, X_te, y_tr, y_te) in processed.items():
    rows = []
    is_wr = (pos == 'WR')

    print(f'\n{"="*60}')
    print(f'  {pos} — Test evaluacija (sezona 2024, n_test={len(X_te)})')
    if is_wr:
        print(f'  [WR: sve metrike na originalnoj yds/g skali (expm1)]')
    print(f'{"="*60}')
    print(f'  {"Model":<20} {"MAE":>8} {"RMSE":>8} {"R²":>8}  {"Best params"}')
    print(f'  {"-"*75}')

    for name, model in best_estimators[pos].items():
        preds = model.predict(X_te)

        if is_wr:
            y_true_inv = np.expm1(y_te)
            y_pred_inv = np.expm1(preds)
            mae  = mean_absolute_error(y_true_inv, y_pred_inv)
            rmse = np.sqrt(mean_squared_error(y_true_inv, y_pred_inv))
            r2   = r2_score(y_true_inv, y_pred_inv)   
        else:
            mae  = mean_absolute_error(y_te, preds)
            rmse = np.sqrt(mean_squared_error(y_te, preds))
            r2   = r2_score(y_te, preds)

        rows.append({'Model': name, 'MAE': mae, 'RMSE': rmse, 'R2': r2})
        best_params_str = cv_results[pos].loc[name, 'Best_params']
        print(f'  {name:<20} {mae:>8.3f} {rmse:>8.3f} {r2:>8.3f}  {best_params_str}')

    df_test = pd.DataFrame(rows).set_index('Model')
    test_results[pos] = df_test

    best_name = df_test['RMSE'].idxmin()
    best_models[pos] = (best_name, best_estimators[pos][best_name])
    print(f'\n  ★ Najbolji model ({pos}): {best_name} | RMSE={df_test.loc[best_name,"RMSE"]:.3f}')

print('\nFinalna test evaluacija završena.')
# Out:
# ============================================================
#   QB — Test evaluacija (sezona 2024, n_test=35)
# ============================================================
#   Model                     MAE     RMSE       R²  Best params
#   ---------------------------------------------------------------------------
#   LinearRegression       34.113   45.809   -0.038  {}
#   Ridge                  33.319   47.885   -0.134  {'alpha': 100.0}
#   Lasso                  31.611   44.484    0.021  {'alpha': 1.0}
#   ElasticNet             33.967   48.599   -0.168  {'alpha': 0.1, 'l1_ratio': 0.1}
#   KNeighbors             33.148   43.847    0.049  {'n_neighbors': 15, 'weights': 'uniform'}
#   RandomForest           31.817   41.650    0.142  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
#   XGBoost                32.368   41.582    0.145  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#   LightGBM               33.140   41.746    0.138  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#
#   ★ Najbolji model (QB): XGBoost | RMSE=41.582
#
# ============================================================
#   RB — Test evaluacija (sezona 2024, n_test=34)
# ============================================================
#   Model                     MAE     RMSE       R²  Best params
#   ---------------------------------------------------------------------------
#   LinearRegression       19.031   23.421    0.118  {}
#   Ridge                  20.345   24.155    0.062  {'alpha': 100.0}
#   Lasso                  20.543   24.373    0.045  {'alpha': 1.0}
#   ElasticNet             20.116   23.990    0.075  {'alpha': 0.1, 'l1_ratio': 0.1}
#   KNeighbors             19.414   23.935    0.079  {'n_neighbors': 15, 'weights': 'distance'}
#   RandomForest           19.114   23.000    0.150  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
#   XGBoost                19.376   23.414    0.119  {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}
#   LightGBM               19.444   23.433    0.117  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#
#   ★ Najbolji model (RB): RandomForest | RMSE=23.000
#
# ============================================================
#   TE — Test evaluacija (sezona 2024, n_test=28)
# ============================================================
#   Model                     MAE     RMSE       R²  Best params
#   ---------------------------------------------------------------------------
#   LinearRegression       13.616   16.538    0.218  {}
#   Ridge                  12.122   14.351    0.411  {'alpha': 100.0}
#   Lasso                  11.707   13.850    0.451  {'alpha': 1.0}
#   ElasticNet             11.770   13.976    0.441  {'alpha': 1.0, 'l1_ratio': 0.1}
#   KNeighbors             12.865   15.763    0.289  {'n_neighbors': 7, 'weights': 'uniform'}
#   RandomForest           12.487   15.157    0.343  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
#   XGBoost                11.670   14.431    0.404  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#   LightGBM               11.787   14.239    0.420  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 15}
#
#   ★ Najbolji model (TE): Lasso | RMSE=13.850
#
# ============================================================
#   WR — Test evaluacija (sezona 2024, n_test=558)
#   [WR: sve metrike na originalnoj yds/g skali (expm1)]
# ============================================================
#   Model                     MAE     RMSE       R²  Best params
#   ---------------------------------------------------------------------------
#   LinearRegression       12.241   18.148    0.160  {}
#   Ridge                  11.980   17.853    0.187  {'alpha': 100.0}
#   Lasso                  12.073   17.988    0.175  {'alpha': 0.01}
#   ElasticNet             12.056   17.963    0.177  {'alpha': 0.01, 'l1_ratio': 0.9}
#   KNeighbors             12.143   16.816    0.279  {'n_neighbors': 15, 'weights': 'uniform'}
#   RandomForest           11.414   16.269    0.325  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
#   XGBoost                11.465   16.416    0.313  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#   LightGBM               11.444   16.394    0.315  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#
#   ★ Najbolji model (WR): RandomForest | RMSE=16.269
#
# Finalna test evaluacija završena.

# %%
print_cv_test_summary(cv_results, test_results, best_models, MODEL_CONFIGS)
save_best_models(best_models, test_results, cv_results)
# Out:
# GridSearchCV CV MAE vs Test rezultati
#
# Pos   Model                  CV_MAE │  Test_MAE  Test_RMSE  Test_R²
# ──────────────────────────────────────────────────────────────────────
# QB    LinearRegression       45.968 │    34.113     45.809   -0.038
#       Ridge                  35.257 │    33.319     47.885   -0.134
#       Lasso                  35.186 │    31.611     44.484    0.021
#       ElasticNet             34.930 │    33.967     48.599   -0.168
#       KNeighbors             36.541 │    33.148     43.847    0.049
#       RandomForest           35.494 │    31.817     41.650    0.142
#       XGBoost                35.643 │    32.368     41.582    0.145 ★
#       LightGBM               35.818 │    33.140     41.746    0.138
# ──────────────────────────────────────────────────────────────────────
# RB    LinearRegression       19.705 │    19.031     23.421    0.118
#       Ridge                  18.004 │    20.345     24.155    0.062
#       Lasso                  18.021 │    20.543     24.373    0.045
#       ElasticNet             17.952 │    20.116     23.990    0.075
#       KNeighbors             18.620 │    19.414     23.935    0.079
#       RandomForest           18.334 │    19.114     23.000    0.150 ★
#       XGBoost                18.675 │    19.376     23.414    0.119
#       LightGBM               18.408 │    19.444     23.433    0.117
# ──────────────────────────────────────────────────────────────────────
# TE    LinearRegression       23.743 │    13.616     16.538    0.218
#       Ridge                  12.021 │    12.122     14.351    0.411
#       Lasso                  12.370 │    11.707     13.850    0.451 ★
#       ElasticNet             12.397 │    11.770     13.976    0.441
#       KNeighbors             12.748 │    12.865     15.763    0.289
#       RandomForest           12.324 │    12.487     15.157    0.343
#       XGBoost                12.568 │    11.670     14.431    0.404
#       LightGBM               12.498 │    11.787     14.239    0.420
# ──────────────────────────────────────────────────────────────────────
# WR    LinearRegression        0.694 │    12.241     18.148    0.160
#       Ridge                   0.681 │    11.980     17.853    0.187
#       Lasso                   0.676 │    12.073     17.988    0.175
#       ElasticNet              0.676 │    12.056     17.963    0.177
#       KNeighbors              0.707 │    12.143     16.816    0.279
#       RandomForest            0.680 │    11.414     16.269    0.325 ★
#       XGBoost                 0.673 │    11.465     16.416    0.313
#       LightGBM                0.672 │    11.444     16.394    0.315
# ──────────────────────────────────────────────────────────────────────
#
# Sačuvani modeli:
#   QB: XGBoost → RMSE=41.582 | params={'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#   RB: RandomForest → RMSE=23.000 | params={'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
#   TE: Lasso → RMSE=13.850 | params={'alpha': 1.0}
#   WR: RandomForest → RMSE=16.269 | params={'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}

# %%
plot_predicted_vs_actual(
    processed, best_models, test_results, lagged,
    test_year=2024,
    annotate_positions=('QB', 'RB', 'TE'),
)

# %% [markdown]
# ### Analiza dobijenih rezultata
#
# Rezultati dobijeni  potvrđuju da se performanse modela značajno razlikuju po pozicijama, ali i da nelinearni modeli u većini slučajeva ostvaruju blagu prednost.
#
# Kod QB pozicije najbolji rezultat postiže XGBoost ($R^2 = 0.145$), uz vrlo slične performanse RandomForest-a ($R^2 = 0.142$) i LightGBM-a ($R^2 = 0.138$). Ovo potvrđuje da je za kvoterbekove prisutna određena nelinearna struktura u podacima, koju stabla odlučivanja uspešnije hvataju od linearnih modela. Ipak, ukupna objašnjena varijansa ostaje niska (oko 14%), što znači da modeli objašnjavaju relativno mali deo realnog učinka QB igrača. Posebno je primetno da LinearRegression, Ridge i ElasticNet imaju negativan $R^2$, što implicira da su lošiji od jednostavne predikcije prosekom.
#
# Kod RB pozicije najbolji model je RandomForest ($R^2 = 0.150$), dok su XGBoost i LightGBM nešto slabiji, ali i dalje konkurentni. Linearni modeli ovde postižu skromne rezultate (maksimalno oko $R^2 = 0.118$), što ponovo sugeriše prisustvo kompleksnih interakcija među atributima. Ipak, kao i kod QB pozicije, ukupna predvidljivost ostaje ograničena, jer modeli objašnjavaju svega oko 15% varijanse performansi.
#
# Pozicija TE se jasno izdvaja kao najpredvidljivija u celom skupu podataka. Najbolji rezultat postiže Lasso regresija ($R^2 = 0.451$), što je ujedno i najviša vrednost determinacije među svim pozicijama. Blizu su i LightGBM ($R^2 = 0.420$) i XGBoost ($R^2 = 0.404$), ali linearni model sa regularizacijom ipak daje najbolju generalizaciju. Ovo ukazuje da su ključni faktori performansi kod TE pozicije u izraženijoj linearnoj korelaciji, dok Lasso dodatno doprinosi eliminacijom manje značajnih varijabli i smanjenjem overfitting-a.
#
# Kod WR pozicije najbolji rezultat ostvaruje RandomForest ($R^2 = 0.325$), dok su LightGBM ($R^2 = 0.315$) i XGBoost ($R^2 = 0.313$) vrlo blizu. Ovde je primetno da i KNN model daje solidan rezultat ($R^2 = 0.279$), što sugeriše postojanje lokalnih obrazaca u podacima. Iako su rezultati bolji nego kod QB i RB pozicija, objašnjena varijansa je i dalje umerenog nivoa (oko 30%), što znači da značajan deo performansi i dalje zavisi od faktora koji nisu uključeni u model.
#
# Generalno posmatrano, nelinearni ansambl modeli (RandomForest, XGBoost, LightGBM) dominiraju kod QB, RB i WR pozicija, dok se kod TE pozicije linearni model sa L1 regularizacijom pokazuje kao optimalno rešenje. Ipak, vrednosti $R^2$ za QB i RB ostaju relativno niske, što potvrđuje da su ove pozicije najteže za precizno modelovanje, verovatno zbog izražene zavisnosti od spoljašnjih faktora koji nisu u potpunosti obuhvaćeni dostupnim atributima.

# %% [markdown]
# ### Kalibracija evaluacije
#
# Kalibracija evaluacije u ovom kontekstu odnosi se na primenu walk-forward validacije (cross-year hold-out) kako bi se simulirali realni uslovi predikcije performansi NFL igrača, gde modeli treniraju isključivo na istorijskim podacima bez curenja informacija iz budućih sezona. Umesto jednog splita (trening pre 2024, test na 2024), koriste se više foldova: trening do 2020 za test na 2021, do 2021 za 2022, itd., sve do 2024, što omogućava evaluaciju stabilnosti modela preko vremena, identifikaciju eventualnih trendova u performansama i bolju procenu generalizacije na neviđene podatke, izbegavajući optimizam jednokratne evaluacije.

# %%
FOLDS = [
    {'name': 'Fold 1', 'train_end': 2020, 'test_year': 2021},
    {'name': 'Fold 2', 'train_end': 2021, 'test_year': 2022},
    {'name': 'Fold 3', 'train_end': 2022, 'test_year': 2023},
    {'name': 'Fold 4', 'train_end': 2023, 'test_year': 2024},
]

POS_SCOL    = {'QB': 'Season', 'RB': 'Season', 'TE': 'Season', 'WR': 'season'}
POS_ID_COLS = {
    'QB': ['Player', 'Season', 'Team'],
    'RB': ['Player', 'Season', 'Team'],
    'TE': ['Player', 'Season', 'Team'],
    'WR': ['receiver_player_name', 'season', 'posteam'],
}

CAL_MODEL_CONFIGS = MODEL_CONFIGS  

cal_records      = []
cal_best_per_pos = {}
cal_best_params  = {}

for pos in ['QB', 'RB', 'TE', 'WR']:
    scol      = POS_SCOL[pos]
    id_cols   = POS_ID_COLS[pos]
    df_full   = lagged[pos]
    is_wr     = (pos == 'WR')
    feat_cols = [c for c in df_full.columns if c not in id_cols + ['target']]

    print(f'\n{"═"*90}')
    print(f'  {pos} — Kalibracija evaluacije (Cross-Year Hold-Out)')
    if is_wr:
        print(f'  [WR: sve metrike na originalnoj yds/g skali — expm1 inverz]')
    print(f'{"═"*90}')

    model_avg_rmse = {}

    for model_name, mcfg in CAL_MODEL_CONFIGS.items():
        fold_mae, fold_rmse, fold_r2 = [], [], []

        for fold in FOLDS:
            tr_df, te_df, X_tr, X_te, y_tr, y_te = prepare_fold_data(
                df_full, scol, feat_cols, fold['train_end'], fold['test_year']
            )
            if tr_df is None:
                continue

            X_tr_i, X_te_i = impute_lag2_and_median(X_tr, X_te)

            X_tr_s, X_te_s = scale_fold(X_tr_i, X_te_i, BINARY_COLS)

            best_model, best_p = fit_fold_model(mcfg, X_tr_s, y_tr, len(X_tr_s))

            mae, rmse, r2, _ = evaluate_fold(best_model, X_te_s, y_te, is_wr)

            fold_mae.append(mae)
            fold_rmse.append(rmse)
            fold_r2.append(r2)

            cal_records.append(dict(
                pos=pos, model=model_name,
                fold=fold['name'], train_end=fold['train_end'], test_year=fold['test_year'],
                n_train=len(tr_df), n_test=len(te_df),
                mae=mae, rmse=rmse, r2=r2,
                best_params=str(best_p),
            ))
            cal_best_params[(pos, model_name, fold['name'])] = best_p

        avg_rmse = np.mean(fold_rmse) if fold_rmse else np.nan
        model_avg_rmse[model_name] = avg_rmse

    best_model_name = print_position_results(
        pos, cal_records, CAL_MODEL_CONFIGS, FOLDS, model_avg_rmse, cal_best_params
    )
    cal_best_per_pos[pos] = best_model_name

cal_df = pd.DataFrame(cal_records)
# Out:
# ══════════════════════════════════════════════════════════════════════════════════════════
#   QB — Kalibracija evaluacije (Cross-Year Hold-Out)
# ══════════════════════════════════════════════════════════════════════════════════════════
#
#   Model                │       Fold 1 (2021)       Fold 2 (2022)       Fold 3 (2023)       Fold 4 (2024)  │   AvgMAE   AvgRMSE   AvgR²
#   ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   LinearRegression     │    59.87 (R²= 0.233)    35.07 (R²= 0.258)    66.05 (R²= 0.168)    45.81 (R²=-0.038)  │   37.172    51.699   0.155
#   Ridge                │    60.49 (R²= 0.217)    36.06 (R²= 0.216)    69.58 (R²= 0.076)    47.89 (R²=-0.134)  │   38.043    53.502   0.094
#   Lasso                │    59.74 (R²= 0.237)    34.72 (R²= 0.273)    69.53 (R²= 0.078)    44.48 (R²= 0.021)  │   37.141    52.119   0.152
#   ElasticNet           │    60.11 (R²= 0.227)    36.07 (R²= 0.216)    69.22 (R²= 0.086)    48.60 (R²=-0.168)  │   38.132    53.501   0.090
#   KNeighbors           │    62.57 (R²= 0.163)    36.99 (R²= 0.175)    74.59 (R²=-0.062)    43.85 (R²= 0.049)  │   38.612    54.499   0.081
#   RandomForest         │    57.39 (R²= 0.296)    34.90 (R²= 0.266)    73.64 (R²=-0.035)    41.65 (R²= 0.142)  │   37.039    51.893   0.167
#   XGBoost              │    56.43 (R²= 0.319)    34.93 (R²= 0.264)    73.31 (R²=-0.025)    41.58 (R²= 0.145)  │   36.748    51.564   0.176
#   LightGBM             │    57.10 (R²= 0.303)    34.64 (R²= 0.277)    73.46 (R²=-0.030)    41.75 (R²= 0.138)  │   37.426    51.737   0.172
#
#   ★ Najbolji model (QB): XGBoost  |  Avg RMSE = 51.564
#
#   Hiperparametri XGBoost po foldu:
#     Fold 1 (train ≤2020): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#     Fold 2 (train ≤2021): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#     Fold 3 (train ≤2022): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#     Fold 4 (train ≤2023): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#   RB — Kalibracija evaluacije (Cross-Year Hold-Out)
# ══════════════════════════════════════════════════════════════════════════════════════════
#
#   Model                │       Fold 1 (2021)       Fold 2 (2022)       Fold 3 (2023)       Fold 4 (2024)  │   AvgMAE   AvgRMSE   AvgR²
#   ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   LinearRegression     │    14.57 (R²= 0.578)    22.06 (R²= 0.101)    19.48 (R²= 0.176)    23.42 (R²= 0.118)  │   16.094    19.883   0.243
#   Ridge                │    14.31 (R²= 0.593)    21.46 (R²= 0.149)    19.59 (R²= 0.166)    24.15 (R²= 0.062)  │   16.021    19.882   0.243
#   Lasso                │    14.85 (R²= 0.562)    22.95 (R²= 0.027)    20.33 (R²= 0.102)    24.37 (R²= 0.045)  │   16.450    20.627   0.184
#   ElasticNet           │    14.40 (R²= 0.588)    21.57 (R²= 0.141)    19.54 (R²= 0.171)    23.99 (R²= 0.075)  │   15.971    19.873   0.244
#   KNeighbors           │    15.10 (R²= 0.547)    20.82 (R²= 0.199)    21.34 (R²= 0.011)    23.93 (R²= 0.079)  │   16.501    20.298   0.209
#   RandomForest         │    15.55 (R²= 0.520)    21.25 (R²= 0.166)    21.05 (R²= 0.038)    23.00 (R²= 0.150)  │   16.491    20.211   0.218
#   XGBoost              │    16.20 (R²= 0.479)    21.92 (R²= 0.113)    20.82 (R²= 0.058)    23.41 (R²= 0.119)  │   16.683    20.587   0.192
#   LightGBM             │    15.51 (R²= 0.522)    21.84 (R²= 0.119)    21.26 (R²= 0.019)    23.43 (R²= 0.117)  │   16.665    20.510   0.194
#
#   ★ Najbolji model (RB): ElasticNet  |  Avg RMSE = 19.873
#
#   Hiperparametri ElasticNet po foldu:
#     Fold 1 (train ≤2020): {'alpha': 0.1, 'l1_ratio': 0.1}
#     Fold 2 (train ≤2021): {'alpha': 0.1, 'l1_ratio': 0.1}
#     Fold 3 (train ≤2022): {'alpha': 0.1, 'l1_ratio': 0.1}
#     Fold 4 (train ≤2023): {'alpha': 0.1, 'l1_ratio': 0.1}
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#   TE — Kalibracija evaluacije (Cross-Year Hold-Out)
# ══════════════════════════════════════════════════════════════════════════════════════════
#
#   Model                │       Fold 1 (2021)       Fold 2 (2022)       Fold 3 (2023)       Fold 4 (2024)  │   AvgMAE   AvgRMSE   AvgR²
#   ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   LinearRegression     │    21.74 (R²=-0.193)    12.07 (R²= 0.444)    13.64 (R²= 0.493)    16.54 (R²= 0.218)  │   12.613    15.996   0.241
#   Ridge                │    15.58 (R²= 0.387)     9.34 (R²= 0.667)    12.94 (R²= 0.544)    14.35 (R²= 0.411)  │   10.869    13.052   0.502
#   Lasso                │    15.15 (R²= 0.421)     9.60 (R²= 0.648)    13.74 (R²= 0.486)    13.85 (R²= 0.451)  │   10.855    13.085   0.502
#   ElasticNet           │    15.59 (R²= 0.387)     9.66 (R²= 0.644)    13.68 (R²= 0.490)    13.98 (R²= 0.441)  │   11.018    13.227   0.490
#   KNeighbors           │    17.70 (R²= 0.209)    12.88 (R²= 0.367)    17.44 (R²= 0.171)    15.76 (R²= 0.289)  │   12.909    15.947   0.259
#   RandomForest         │    14.58 (R²= 0.463)    11.58 (R²= 0.489)    14.90 (R²= 0.395)    15.16 (R²= 0.343)  │   11.535    14.053   0.423
#   XGBoost              │    14.56 (R²= 0.465)    11.57 (R²= 0.489)    13.96 (R²= 0.469)    14.43 (R²= 0.404)  │   11.149    13.630   0.457
#   LightGBM             │    14.18 (R²= 0.492)    11.85 (R²= 0.464)    14.70 (R²= 0.411)    14.24 (R²= 0.420)  │   11.144    13.743   0.447
#
#   ★ Najbolji model (TE): Ridge  |  Avg RMSE = 13.052
#
#   Hiperparametri Ridge po foldu:
#     Fold 1 (train ≤2020): {'alpha': 100.0}
#     Fold 2 (train ≤2021): {'alpha': 100.0}
#     Fold 3 (train ≤2022): {'alpha': 100.0}
#     Fold 4 (train ≤2023): {'alpha': 100.0}
#
# ══════════════════════════════════════════════════════════════════════════════════════════
#   WR — Kalibracija evaluacije (Cross-Year Hold-Out)
#   [WR: sve metrike na originalnoj yds/g skali — expm1 inverz]
# ══════════════════════════════════════════════════════════════════════════════════════════
#
#   Model                │       Fold 1 (2021)       Fold 2 (2022)       Fold 3 (2023)       Fold 4 (2024)  │   AvgMAE   AvgRMSE   AvgR²
#   ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   LinearRegression     │    19.22 (R²= 0.088)    16.99 (R²= 0.255)    15.89 (R²= 0.400)    18.15 (R²= 0.160)  │   11.600    17.562   0.226
#   Ridge                │    18.42 (R²= 0.162)    16.94 (R²= 0.260)    16.11 (R²= 0.384)    17.85 (R²= 0.187)  │   11.465    17.329   0.248
#   Lasso                │    17.45 (R²= 0.248)    16.91 (R²= 0.262)    15.82 (R²= 0.405)    17.99 (R²= 0.175)  │   11.408    17.044   0.273
#   ElasticNet           │    17.64 (R²= 0.232)    16.65 (R²= 0.285)    15.83 (R²= 0.405)    17.96 (R²= 0.177)  │   11.421    17.020   0.275
#   KNeighbors           │    17.14 (R²= 0.275)    16.04 (R²= 0.336)    16.44 (R²= 0.358)    16.82 (R²= 0.279)  │   11.710    16.608   0.312
#   RandomForest         │    17.40 (R²= 0.252)    16.52 (R²= 0.296)    16.02 (R²= 0.391)    16.27 (R²= 0.325)  │   11.257    16.552   0.316
#   XGBoost              │    17.05 (R²= 0.282)    16.17 (R²= 0.325)    16.19 (R²= 0.377)    16.42 (R²= 0.313)  │   11.184    16.457   0.324
#   LightGBM             │    16.91 (R²= 0.293)    16.12 (R²= 0.330)    16.23 (R²= 0.374)    16.39 (R²= 0.315)  │   11.179    16.414   0.328
#
#   ★ Najbolji model (WR): LightGBM  |  Avg RMSE = 16.414
#
#   Hiperparametri LightGBM po foldu:
#     Fold 1 (train ≤2020): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#     Fold 2 (train ≤2021): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#     Fold 3 (train ≤2022): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#     Fold 4 (train ≤2023): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}

# %%
import matplotlib.pyplot as plt

POSITIONS  = ['QB', 'RB', 'TE', 'WR']
colors_pos = {'QB': '#3498db', 'RB': '#e74c3c', 'TE': '#9b59b6', 'WR': '#2ecc71'}

fig, axes = plt.subplots(2, 2, figsize=(20, 14))

plot_rmse_by_fold(axes[0, 0], cal_df, cal_best_per_pos, POSITIONS, colors_pos)
plot_r2_by_fold  (axes[0, 1], cal_df, cal_best_per_pos, POSITIONS, colors_pos)
plot_train_size  (axes[1, 0], cal_df, cal_best_per_pos, POSITIONS, colors_pos)
plot_avg_rmse_bar(axes[1, 1], cal_df, cal_best_per_pos, POSITIONS, CAL_MODEL_CONFIGS, colors_pos)

plt.suptitle('Kalibracija evaluacije — Cross-Year Hold-Out\n'
             'Svaki fold = potpuno svježi imputer + scaler + GridSearchCV + trening  |  0 data leakage',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print_calibration_details(cal_df, cal_best_per_pos, cal_best_params, POSITIONS)
# Out:
# ═══════════════════════════════════════════════════════════════════════════════════════════════
# DETALJNI REZULTATI PO POZICIJI I FOLDU (sa parametrima)
# ═══════════════════════════════════════════════════════════════════════════════════════════════
#
# QB  (★ Najbolji avg RMSE: XGBoost)
# Train/test veličine:   2021: train=617, test=33  2022: train=650, test=31  2023: train=681, test=33  2024: train=714, test=35
#                   RMSE_2021  RMSE_2022  RMSE_2023  RMSE_2024  R²_2021  R²_2022  R²_2023  R²_2024  AvgRMSE  AvgR2
# model
# ElasticNet            60.11      36.07      69.22      48.60    0.227    0.216    0.086   -0.168   53.501  0.090
# KNeighbors            62.57      36.99      74.59      43.85    0.163    0.175   -0.062    0.049   54.499  0.081
# Lasso                 59.74      34.72      69.53      44.48    0.237    0.273    0.078    0.021   52.119  0.152
# LightGBM              57.10      34.64      73.46      41.75    0.303    0.277   -0.030    0.138   51.737  0.172
# LinearRegression      59.87      35.07      66.05      45.81    0.233    0.258    0.168   -0.038   51.699  0.155
# RandomForest          57.39      34.90      73.64      41.65    0.296    0.266   -0.035    0.142   51.893  0.167
# Ridge                 60.49      36.06      69.58      47.89    0.217    0.216    0.076   -0.134   53.502  0.094
# XGBoost               56.43      34.93      73.31      41.58    0.319    0.264   -0.025    0.145   51.564  0.176
#
#   Parametri XGBoost po foldu:
#     Train≤2020 → Test 2021: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#     Train≤2021 → Test 2022: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#     Train≤2022 → Test 2023: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#     Train≤2023 → Test 2024: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
#
# RB  (★ Najbolji avg RMSE: ElasticNet)
# Train/test veličine:   2021: train=456, test=27  2022: train=483, test=33  2023: train=516, test=36  2024: train=552, test=34
#                   RMSE_2021  RMSE_2022  RMSE_2023  RMSE_2024  R²_2021  R²_2022  R²_2023  R²_2024  AvgRMSE  AvgR2
# model
# ElasticNet            14.40      21.57      19.54      23.99    0.588    0.141    0.171    0.075   19.873  0.244
# KNeighbors            15.10      20.82      21.34      23.93    0.547    0.199    0.011    0.079   20.298  0.209
# Lasso                 14.85      22.95      20.33      24.37    0.562    0.027    0.102    0.045   20.627  0.184
# LightGBM              15.51      21.84      21.26      23.43    0.522    0.119    0.019    0.117   20.510  0.194
# LinearRegression      14.57      22.06      19.48      23.42    0.578    0.101    0.176    0.118   19.883  0.243
# RandomForest          15.55      21.25      21.05      23.00    0.520    0.166    0.038    0.150   20.211  0.218
# Ridge                 14.31      21.46      19.59      24.15    0.593    0.149    0.166    0.062   19.882  0.243
# XGBoost               16.20      21.92      20.82      23.41    0.479    0.113    0.058    0.119   20.587  0.192
#
#   Parametri ElasticNet po foldu:
#     Train≤2020 → Test 2021: {'alpha': 0.1, 'l1_ratio': 0.1}
#     Train≤2021 → Test 2022: {'alpha': 0.1, 'l1_ratio': 0.1}
#     Train≤2022 → Test 2023: {'alpha': 0.1, 'l1_ratio': 0.1}
#     Train≤2023 → Test 2024: {'alpha': 0.1, 'l1_ratio': 0.1}
#
# TE  (★ Najbolji avg RMSE: Ridge)
# Train/test veličine:   2021: train=216, test=25  2022: train=241, test=25  2023: train=266, test=29  2024: train=295, test=28
#                   RMSE_2021  RMSE_2022  RMSE_2023  RMSE_2024  R²_2021  R²_2022  R²_2023  R²_2024  AvgRMSE  AvgR2
# model
# ElasticNet            15.59       9.66      13.68      13.98    0.387    0.644    0.490    0.441   13.227  0.490
# KNeighbors            17.70      12.88      17.44      15.76    0.209    0.367    0.171    0.289   15.947  0.259
# Lasso                 15.15       9.60      13.74      13.85    0.421    0.648    0.486    0.451   13.085  0.502
# LightGBM              14.18      11.85      14.70      14.24    0.492    0.464    0.411    0.420   13.743  0.447
# LinearRegression      21.74      12.07      13.64      16.54   -0.193    0.444    0.493    0.218   15.996  0.241
# RandomForest          14.58      11.58      14.90      15.16    0.463    0.489    0.395    0.343   14.053  0.423
# Ridge                 15.58       9.34      12.94      14.35    0.387    0.667    0.544    0.411   13.052  0.502
# XGBoost               14.56      11.57      13.96      14.43    0.465    0.489    0.469    0.404   13.630  0.457
#
#   Parametri Ridge po foldu:
#     Train≤2020 → Test 2021: {'alpha': 100.0}
#     Train≤2021 → Test 2022: {'alpha': 100.0}
#     Train≤2022 → Test 2023: {'alpha': 100.0}
#     Train≤2023 → Test 2024: {'alpha': 100.0}
#
# WR  (★ Najbolji avg RMSE: LightGBM)
# Train/test veličine:   2021: train=3436, test=709  2022: train=4145, test=655  2023: train=4800, test=593  2024: train=5393, test=558
#                   RMSE_2021  RMSE_2022  RMSE_2023  RMSE_2024  R²_2021  R²_2022  R²_2023  R²_2024  AvgRMSE  AvgR2
# model
# ElasticNet            17.64      16.65      15.83      17.96    0.232    0.285    0.405    0.177   17.020  0.275
# KNeighbors            17.14      16.04      16.44      16.82    0.275    0.336    0.358    0.279   16.608  0.312
# Lasso                 17.45      16.91      15.82      17.99    0.248    0.262    0.405    0.175   17.044  0.273
# LightGBM              16.91      16.12      16.23      16.39    0.293    0.330    0.374    0.315   16.414  0.328
# LinearRegression      19.22      16.99      15.89      18.15    0.088    0.255    0.400    0.160   17.562  0.226
# RandomForest          17.40      16.52      16.02      16.27    0.252    0.296    0.391    0.325   16.552  0.316
# Ridge                 18.42      16.94      16.11      17.85    0.162    0.260    0.384    0.187   17.329  0.248
# XGBoost               17.05      16.17      16.19      16.42    0.282    0.325    0.377    0.313   16.457  0.324
#
#   Parametri LightGBM po foldu:
#     Train≤2020 → Test 2021: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#     Train≤2021 → Test 2022: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#     Train≤2022 → Test 2023: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}
#     Train≤2023 → Test 2024: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'num_leaves': 15}

# %%
all_preds = plot_walkforward_predicted_vs_actual(
    best_models        = best_models,
    lagged             = lagged,
    pos_id_cols        = POS_ID_COLS,
    binary_cols        = BINARY_COLS,
    cal_model_configs  = CAL_MODEL_CONFIGS,
    cal_best_params    = cal_best_params,
    positions          = ['QB', 'RB', 'TE', 'WR'],
    annotate_positions = ('QB', 'RB', 'TE'),
)
# Out:
# QB — treniranje po foldu (XGBoost) ...
#   → 132 predikcija prikupljeno (4 folda)
# RB — treniranje po foldu (RandomForest) ...
#   → 130 predikcija prikupljeno (4 folda)
# TE — treniranje po foldu (Lasso) ...
#   → 107 predikcija prikupljeno (4 folda)
# WR — treniranje po foldu (RandomForest) ...
#   → 2515 predikcija prikupljeno (4 folda)
# ════════════════════════════════════════════════════════════════════
#   Pregled metrika po poziciji i test godini (walk-forward)
# ════════════════════════════════════════════════════════════════════
#   Pos    Godina     N       MAE      RMSE       R²
#   ──────────────────────────────────────────────────────────
#   QB       2021    33    37.949    56.431    0.319
#   QB       2022    31    28.238    34.935    0.264
#   QB       2023    33    48.436    73.309   -0.025
#   QB       2024    35    32.368    41.582    0.145
#   QB        AVG   132    36.810    53.710    0.169
#   ──────────────────────────────────────────────────────────
#   RB       2021    27    12.511    15.547    0.520
#   RB       2022    33    17.701    21.249    0.166
#   RB       2023    36    16.640    21.048    0.038
#   RB       2024    34    19.114    23.000    0.150
#   RB        AVG   130    16.699    20.636    0.208
#   ──────────────────────────────────────────────────────────
#   TE       2021    25    12.109    15.149    0.421
#   TE       2022    25     8.393     9.600    0.648
#   TE       2023    29    11.211    13.741    0.486
#   TE       2024    28    11.707    13.850    0.451
#   TE        AVG   107    10.892    13.286    0.494
#   ──────────────────────────────────────────────────────────
#   WR       2021   709    11.793    17.403    0.252
#   WR       2022   655    11.269    16.518    0.296
#   WR       2023   593    10.550    16.018    0.391
#   WR       2024   558    11.414    16.269    0.325
#   WR        AVG  2515    11.279    16.603    0.314
#   ──────────────────────────────────────────────────────────

# %% [markdown]
# Rezultati dobijeni kroz rolling expanding window evaluaciju (trening do 2020 → test 2021, zatim progresivno do 2024) potvrđuju stabilnost modela kroz vreme, ali i jasno diferenciraju pozicije po stepenu predvidljivosti.
#
# Kod QB pozicije najbolji prosečan RMSE ostvaruje XGBoost (AvgRMSE = 51.564, AvgR² = 0.176), uz vrlo bliske rezultate LightGBM-a i RandomForest-a. Ipak, vrednosti $R^2$ variraju po sezonama – dok su 2021. i 2022. relativno solidne (oko 0.30), 2023. beleži pad i čak negativne vrednosti kod većine modela. Ovo ukazuje na izraženu nestabilnost i vremensku varijabilnost performansi QB igrača. Linearni modeli (Ridge, ElasticNet, LinearRegression) ne zaostaju drastično u proseku, ali nijedan model ne prelazi prosečnih 18% objašnjene varijanse, što potvrđuje da QB ostaje veoma težak za dugoročno generalizovano modelovanje.
#
# Kod RB pozicije situacija je drugačija – najbolji prosečan rezultat postiže ElasticNet (AvgRMSE = 19.873, AvgR² = 0.244), praktično izjednačen sa Ridge i LinearRegression modelima. Zanimljivo je da ovde linearni modeli nadmašuju ansambl metode, što sugeriše stabilniju i linearniju strukturu odnosa između atributa i ciljne promenljive. Ipak, vidi se izražen pad performansi nakon 2021. (R² sa 0.58 pada na ~0.07–0.17 u narednim sezonama), što može ukazivati na promene u dinamici igre ili distribuciji podataka kroz vreme.
#
# Pozicija TE se ponovo izdvaja kao najpredvidljivija. Najniži prosečan RMSE ima Ridge (AvgRMSE = 13.052, AvgR² = 0.502), gotovo identično kao Lasso. Vrednosti $R^2$ su dosledno visoke (0.41–0.67), posebno u sezonama 2022. i 2023. gde prelaze 0.5. Ovo potvrđuje da su performanse TE igrača u snažnoj i stabilnoj linearnoj korelaciji sa izabranim atributima, dok regularizacija (α=100) doprinosi boljoj generalizaciji kroz različite vremenske foldove. Za razliku od QB i RB, ovde je vremenska stabilnost modela znatno izraženija.
#
# Kod WR pozicije najbolji prosečan rezultat ostvaruje LightGBM (AvgRMSE = 16.414, AvgR² = 0.328), vrlo blizu su XGBoost i RandomForest. $R^2$ vrednosti su umerene (0.29–0.40), sa blagim padom u 2024. godini. Ansambl modeli imaju konzistentnu prednost u odnosu na čisto linearne pristupe, što sugeriše postojanje nelinearnih obrazaca u velikom i heterogenom WR skupu (koji je višestruko veći od ostalih pozicija). Ipak, objašnjena varijansa ostaje oko 30%, što znači da značajan deo performansi i dalje zavisi od faktora koji nisu eksplicitno modelovani.
